# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
def execute_trading_strategy(ticker_symbol, start_date, end_date):
    stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)

    ohlc_data = stock_data[['Open', 'High', 'Low', 'Close']]

    short_ema = ohlc_data['Close'].ewm(span=13, min_periods=0, adjust=False).mean()
    long_ema = ohlc_data['Close'].ewm(span=21, min_periods=0, adjust=False).mean()

    macd = short_ema - long_ema
    signal_line = macd.ewm(span=7, min_periods=0, adjust=False).mean()

    ohlc_data['MACD'] = macd
    ohlc_data['Signal Line'] = signal_line

    window = 20 
    num_std = 0.7 

    ohlc_data['Middle Band'] = ohlc_data['Close'].rolling(window=window).mean()
    ohlc_data['Upper Band'] = ohlc_data['Middle Band'] + (ohlc_data['Close'].rolling(window=window).std() * num_std)

    conversion_line_period = 9
    base_line_period = 26
    leading_span_b_period = 52
    displacement = 26

    tenkan_sen_high = ohlc_data['High'].rolling(window=conversion_line_period).max()
    tenkan_sen_low = ohlc_data['Low'].rolling(window=conversion_line_period).min()
    ohlc_data['Tenkan-sen'] = (tenkan_sen_high + tenkan_sen_low) / 2

    kijun_sen_high = ohlc_data['High'].rolling(window=base_line_period).max()
    kijun_sen_low = ohlc_data['Low'].rolling(window=base_line_period).min()
    ohlc_data['Kijun-sen'] = (kijun_sen_high + kijun_sen_low) / 2

    in_trade = False
    buy_price = 0
    sell_price = 0
    trade_count = 0
    total_profit = 0

    buy_dates = []
    buy_prices = []
    sell_dates = []
    sell_prices = []
    profits = []

    for index, row in ohlc_data.iterrows():
        if not in_trade:
            # Entry conditions
            if (
                row['Close'] > row['Upper Band'] and
                row['MACD'] > row['Signal Line'] and
                row['Tenkan-sen'] > row['Kijun-sen']
            ):
                in_trade = True
                buy_price = row['Close']
                buy_dates.append(index.date())
                buy_prices.append(buy_price)
                print(f"{ticker_symbol}: Buy at {index.date()} - Price: {buy_price}")
        else:
            # Exit conditions
            if not (
                row['Close'] > row['Upper Band'] and
                row['Signal Line'] > 0 and
                row['Tenkan-sen'] > row['Kijun-sen']
            ):
                sell_price = row['Close']
                profit = sell_price - buy_price
                total_profit += profit
                trade_count += 1
                sell_dates.append(index.date())
                sell_prices.append(sell_price)
                profits.append(profit)
                print(f"{ticker_symbol}: Sell at {index.date()} - Price: {sell_price} - Profit: {profit:.2f}")
                in_trade = False

    min_length = min(len(buy_dates), len(buy_prices), len(sell_dates), len(sell_prices), len(profits))

    df_trades = pd.DataFrame({
        'Buy Date': buy_dates[:min_length],
        'Buy Price': buy_prices[:min_length],
        'Sell Date': sell_dates[:min_length],
        'Sell Price': sell_prices[:min_length],
        'Profit': profits[:min_length]
    })

    df_trades.to_csv(f'{ticker_symbol}_trades_output.csv', index=False)

    if trade_count > 0:
        avg_profit_per_trade = total_profit / trade_count
        print(f"\n{ticker_symbol}: Total Trades: {trade_count}")
        print(f"{ticker_symbol}: Total Profit: {total_profit:.2f}")
        print(f"{ticker_symbol}: Average Profit per Trade: {avg_profit_per_trade:.2f}")
    else:
        print(f"{ticker_symbol}: No trades executed based on the strategy.")

ticker_symbols = ['^NSEI', '^NSEBANK', 'RELIANCE.NS', 'SBIN.NS']


start_date = '2020-01-01'
end_date = '2023-12-31'

for symbol in ticker_symbols:
    execute_trading_strategy(symbol, start_date, end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ^NSEI: Buy at 2020-04-22 - Price: 9187.2998046875
# ^NSEI: Sell at 2020-04-23 - Price: 9313.900390625 - Profit: 126.60
# ^NSEI: Buy at 2020-04-24 - Price: 9154.400390625
# ^NSEI: Sell at 2020-04-27 - Price: 9282.2998046875 - Profit: 127.90
# ^NSEI: Buy at 2020-04-28 - Price: 9380.900390625
# ^NSEI: Sell at 2020-04-29 - Price: 9553.349609375 - Profit: 172.45
# ^NSEI: Buy at 2020-04-30 - Price: 9859.900390625
# ^NSEI: Sell at 2020-05-04 - Price: 9293.5 - Profit: -566.40
# ^NSEI: Buy at 2020-06-01 - Price: 9826.150390625
# ^NSEI: Sell at 2020-06-15 - Price: 9813.7001953125 - Profit: -12.45
# ^NSEI: Buy at 2020-06-22 - Price: 10311.2001953125
# ^NSEI: Sell at 2020-07-14 - Price: 10607.349609375 - Profit: 296.15
# ^NSEI: Buy at 2020-07-21 - Price: 11162.25
# ^NSEI: Sell at 2020-07-31 - Price: 11073.4501953125 - Profit: -88.80
# ^NSEI: Buy at 2020-08-26 - Price: 11549.599609375
# ^NSEI: Sell at 2020-08-31 - Price: 11387.5 - Profit: -162.10
# ^NSEI: Buy at 2020-10-08 - Price: 11834.599609375
# ^NSEI: Sell at 2020-10-15 - Price: 11680.349609375 - Profit: -154.25
# ^NSEI: Buy at 2020-10-16 - Price: 11762.4501953125
# ^NSEI: Sell at 2020-10-26 - Price: 11767.75 - Profit: 5.30
# ^NSEI: Buy at 2020-11-05 - Price: 12120.2998046875
# ^NSEI: Sell at 2020-11-10 - Price: 12631.099609375 - Profit: 510.80
# ^NSEI: Buy at 2020-11-12 - Price: 12690.7998046875
# ^NSEI: Sell at 2020-12-21 - Price: 13328.400390625 - Profit: 637.60
# ^NSEI: Buy at 2020-12-30 - Price: 13981.9501953125
# ^NSEI: Sell at 2021-01-18 - Price: 14281.2998046875 - Profit: 299.35
# ^NSEI: Buy at 2021-02-11 - Price: 15173.2998046875
# ^NSEI: Sell at 2021-02-19 - Price: 14981.75 - Profit: -191.55
# ^NSEI: Buy at 2021-05-07 - Price: 14823.150390625
# ^NSEI: Sell at 2021-05-10 - Price: 14942.349609375 - Profit: 119.20
# ^NSEI: Buy at 2021-05-11 - Price: 14850.75
# ^NSEI: Sell at 2021-05-12 - Price: 14696.5 - Profit: -154.25
# ^NSEI: Buy at 2021-05-17 - Price: 14923.150390625
# ^NSEI: Sell at 2021-06-17 - Price: 15691.400390625 - Profit: 768.25
# ^NSEI: Buy at 2021-07-16 - Price: 15923.400390625
# ^NSEI: Sell at 2021-07-19 - Price: 15752.400390625 - Profit: -171.00
# ^NSEI: Buy at 2021-08-10 - Price: 16280.099609375
# ^NSEI: Sell at 2021-09-20 - Price: 17396.900390625 - Profit: 1116.80
# ^NSEI: Buy at 2021-09-24 - Price: 17853.19921875
# ^NSEI: Sell at 2021-09-30 - Price: 17618.150390625 - Profit: -235.05
# ^NSEI: Buy at 2021-10-13 - Price: 18161.75
# ^NSEI: Sell at 2021-10-22 - Price: 18114.900390625 - Profit: -46.85
# ^NSEI: Buy at 2021-12-31 - Price: 17354.05078125
# ^NSEI: Sell at 2022-01-03 - Price: 17625.69921875 - Profit: 271.65
# ^NSEI: Buy at 2022-01-04 - Price: 17805.25
# ^NSEI: Sell at 2022-01-05 - Price: 17925.25 - Profit: 120.00
# ^NSEI: Buy at 2022-01-06 - Price: 17745.900390625
# ^NSEI: Sell at 2022-01-19 - Price: 17938.400390625 - Profit: 192.50
# ^NSEI: Buy at 2022-03-22 - Price: 17315.5
# ^NSEI: Sell at 2022-03-23 - Price: 17245.650390625 - Profit: -69.85
# ^NSEI: Buy at 2022-03-24 - Price: 17222.75
# ^NSEI: Sell at 2022-03-25 - Price: 17153.0 - Profit: -69.75
# ^NSEI: Buy at 2022-03-28 - Price: 17222.0
# ^NSEI: Sell at 2022-04-12 - Price: 17530.30078125 - Profit: 308.30
# ^NSEI: Buy at 2022-07-12 - Price: 16058.2998046875
# ^NSEI: Sell at 2022-07-13 - Price: 15966.650390625 - Profit: -91.65
# ^NSEI: Buy at 2022-07-15 - Price: 16049.2001953125
# ^NSEI: Sell at 2022-08-22 - Price: 17490.69921875 - Profit: 1441.50
# ^NSEI: Buy at 2022-09-13 - Price: 18070.05078125
# ^NSEI: Sell at 2022-09-16 - Price: 17530.849609375 - Profit: -539.20
# ^NSEI: Buy at 2022-10-24 - Price: 17730.75
# ^NSEI: Sell at 2022-11-21 - Price: 18159.94921875 - Profit: 429.20
# ^NSEI: Buy at 2022-11-29 - Price: 18618.05078125
# ^NSEI: Sell at 2022-12-07 - Price: 18560.5 - Profit: -57.55
# ^NSEI: Buy at 2023-02-15 - Price: 18015.849609375
# ^NSEI: Sell at 2023-02-16 - Price: 18035.849609375 - Profit: 20.00
# ^NSEI: Buy at 2023-04-11 - Price: 17722.30078125
# ^NSEI: Sell at 2023-04-12 - Price: 17812.400390625 - Profit: 90.10
# ^NSEI: Buy at 2023-04-13 - Price: 17828.0
# ^NSEI: Sell at 2023-04-21 - Price: 17624.05078125 - Profit: -203.95
# ^NSEI: Buy at 2023-04-24 - Price: 17743.400390625
# ^NSEI: Sell at 2023-05-17 - Price: 18181.75 - Profit: 438.35
# ^NSEI: Buy at 2023-05-29 - Price: 18598.650390625
# ^NSEI: Sell at 2023-06-09 - Price: 18563.400390625 - Profit: -35.25
# ^NSEI: Buy at 2023-06-21 - Price: 18856.849609375
# ^NSEI: Sell at 2023-06-23 - Price: 18665.5 - Profit: -191.35
# ^NSEI: Buy at 2023-06-30 - Price: 19189.05078125
# ^NSEI: Sell at 2023-07-27 - Price: 19659.900390625 - Profit: 470.85
# ^NSEI: Buy at 2023-09-13 - Price: 20070.0
# ^NSEI: Sell at 2023-09-21 - Price: 19742.349609375 - Profit: -327.65
# ^NSEI: Buy at 2023-11-15 - Price: 19675.44921875
# ^NSEI: Sell at 2023-11-16 - Price: 19765.19921875 - Profit: 89.75
# ^NSEI: Buy at 2023-11-17 - Price: 19731.80078125
# ^NSEI: Sell at 2023-11-20 - Price: 19694.0 - Profit: -37.80
# ^NSEI: Buy at 2023-11-21 - Price: 19783.400390625
#
# ^NSEI: Total Trades: 42
# ^NSEI: Total Profit: 4645.90
# ^NSEI: Average Profit per Trade: 110.62
# [*********************100%%**********************]  1 of 1 completed
# ^NSEBANK: Buy at 2020-04-27 - Price: 20081.150390625
# ^NSEBANK: Sell at 2020-04-28 - Price: 20671.099609375 - Profit: 589.95
# ^NSEBANK: Buy at 2020-04-29 - Price: 21090.19921875
# ^NSEBANK: Sell at 2020-04-30 - Price: 21534.5 - Profit: 444.30
# ^NSEBANK: Buy at 2020-06-08 - Price: 21187.349609375
# ^NSEBANK: Sell at 2020-06-15 - Price: 19912.900390625 - Profit: -1274.45
# ^NSEBANK: Buy at 2020-06-18 - Price: 20956.30078125
# ^NSEBANK: Sell at 2020-06-29 - Price: 21359.0 - Profit: 402.70
# ^NSEBANK: Buy at 2020-07-01 - Price: 21977.599609375
# ^NSEBANK: Sell at 2020-07-13 - Price: 22089.25 - Profit: 111.65
# ^NSEBANK: Buy at 2020-07-22 - Price: 22882.599609375
# ^NSEBANK: Sell at 2020-07-27 - Price: 21848.75 - Profit: -1033.85
# ^NSEBANK: Buy at 2020-08-24 - Price: 22833.0
# ^NSEBANK: Sell at 2020-09-04 - Price: 23011.5 - Profit: 178.50
# ^NSEBANK: Buy at 2020-10-09 - Price: 23846.80078125
# ^NSEBANK: Sell at 2020-10-29 - Price: 24092.0 - Profit: 245.20
# ^NSEBANK: Buy at 2020-11-03 - Price: 25682.80078125
# ^NSEBANK: Sell at 2020-12-03 - Price: 29448.75 - Profit: 3765.95
# ^NSEBANK: Buy at 2021-01-05 - Price: 31722.25
# ^NSEBANK: Sell at 2021-01-18 - Price: 31811.75 - Profit: 89.50
# ^NSEBANK: Buy at 2021-02-10 - Price: 35783.1015625
# ^NSEBANK: Sell at 2021-02-19 - Price: 35841.6015625 - Profit: 58.50
# ^NSEBANK: Buy at 2021-05-07 - Price: 32904.5
# ^NSEBANK: Sell at 2021-05-10 - Price: 33142.3984375 - Profit: 237.90
# ^NSEBANK: Buy at 2021-05-17 - Price: 33459.25
# ^NSEBANK: Sell at 2021-05-18 - Price: 33922.3984375 - Profit: 463.15
# ^NSEBANK: Buy at 2021-05-19 - Price: 33685.19921875
# ^NSEBANK: Sell at 2021-06-08 - Price: 35085.30078125 - Profit: 1400.10
# ^NSEBANK: Buy at 2021-07-06 - Price: 35579.1484375
# ^NSEBANK: Sell at 2021-07-09 - Price: 35071.94921875 - Profit: -507.20
# ^NSEBANK: Buy at 2021-07-13 - Price: 35673.3984375
# ^NSEBANK: Sell at 2021-07-19 - Price: 35079.19921875 - Profit: -594.20
# ^NSEBANK: Buy at 2021-08-10 - Price: 36034.1015625
# ^NSEBANK: Sell at 2021-08-18 - Price: 35554.5 - Profit: -479.60
# ^NSEBANK: Buy at 2021-08-30 - Price: 36347.6484375
# ^NSEBANK: Sell at 2021-09-13 - Price: 36471.80078125 - Profit: 124.15
# ^NSEBANK: Buy at 2021-09-14 - Price: 36613.05078125
# ^NSEBANK: Sell at 2021-09-22 - Price: 36944.6484375 - Profit: 331.60
# ^NSEBANK: Buy at 2021-09-23 - Price: 37771.69921875
# ^NSEBANK: Sell at 2021-09-30 - Price: 37425.1015625 - Profit: -346.60
# ^NSEBANK: Buy at 2021-10-12 - Price: 38521.5
# ^NSEBANK: Sell at 2021-10-28 - Price: 39508.94921875 - Profit: 987.45
# ^NSEBANK: Buy at 2022-01-05 - Price: 37695.8984375
# ^NSEBANK: Sell at 2022-01-06 - Price: 37490.25 - Profit: -205.65
# ^NSEBANK: Buy at 2022-01-07 - Price: 37739.6015625
# ^NSEBANK: Sell at 2022-01-10 - Price: 38347.8984375 - Profit: 608.30
# ^NSEBANK: Buy at 2022-01-11 - Price: 38442.19921875
# ^NSEBANK: Sell at 2022-01-20 - Price: 37850.8515625 - Profit: -591.35
# ^NSEBANK: Buy at 2022-02-02 - Price: 39330.5
# ^NSEBANK: Sell at 2022-02-07 - Price: 37995.44921875 - Profit: -1335.05
# ^NSEBANK: Buy at 2022-03-30 - Price: 36334.30078125
# ^NSEBANK: Sell at 2022-03-31 - Price: 36373.6015625 - Profit: 39.30
# ^NSEBANK: Buy at 2022-04-01 - Price: 37148.5
# ^NSEBANK: Sell at 2022-04-04 - Price: 38635.19921875 - Profit: 1486.70
# ^NSEBANK: Buy at 2022-04-05 - Price: 38067.8984375
# ^NSEBANK: Sell at 2022-04-18 - Price: 36729.0 - Profit: -1338.90
# ^NSEBANK: Buy at 2022-06-01 - Price: 35620.80078125
# ^NSEBANK: Sell at 2022-06-02 - Price: 35613.6484375 - Profit: -7.15
# ^NSEBANK: Buy at 2022-06-03 - Price: 35275.05078125
# ^NSEBANK: Sell at 2022-06-06 - Price: 35310.19921875 - Profit: 35.15
# ^NSEBANK: Buy at 2022-07-08 - Price: 35124.05078125
# ^NSEBANK: Sell at 2022-07-11 - Price: 35469.6484375 - Profit: 345.60
# ^NSEBANK: Buy at 2022-07-12 - Price: 35132.25
# ^NSEBANK: Sell at 2022-08-22 - Price: 38297.75 - Profit: 3165.50
# ^NSEBANK: Buy at 2022-09-09 - Price: 40415.69921875
# ^NSEBANK: Sell at 2022-09-22 - Price: 40630.6015625 - Profit: 214.90
# ^NSEBANK: Buy at 2022-10-21 - Price: 40784.05078125
# ^NSEBANK: Sell at 2022-12-15 - Price: 43498.19921875 - Profit: 2714.15
# ^NSEBANK: Buy at 2023-04-05 - Price: 40999.1484375
# ^NSEBANK: Sell at 2023-04-06 - Price: 41041.0 - Profit: 41.85
# ^NSEBANK: Buy at 2023-04-10 - Price: 40834.6484375
# ^NSEBANK: Sell at 2023-04-11 - Price: 41366.5 - Profit: 531.85
# ^NSEBANK: Buy at 2023-04-12 - Price: 41557.94921875
# ^NSEBANK: Sell at 2023-05-05 - Price: 42661.19921875 - Profit: 1103.25
# ^NSEBANK: Buy at 2023-05-15 - Price: 44072.1015625
# ^NSEBANK: Sell at 2023-05-24 - Price: 43677.8515625 - Profit: -394.25
# ^NSEBANK: Buy at 2023-07-04 - Price: 45301.44921875
# ^NSEBANK: Sell at 2023-07-11 - Price: 44745.05078125 - Profit: -556.40
# ^NSEBANK: Buy at 2023-07-17 - Price: 45449.75
# ^NSEBANK: Sell at 2023-07-27 - Price: 45679.30078125 - Profit: 229.55
# ^NSEBANK: Buy at 2023-09-08 - Price: 45156.3984375
# ^NSEBANK: Sell at 2023-09-11 - Price: 45570.69921875 - Profit: 414.30
# ^NSEBANK: Buy at 2023-09-12 - Price: 45511.3515625
# ^NSEBANK: Sell at 2023-09-20 - Price: 45384.6015625 - Profit: -126.75
# ^NSEBANK: Buy at 2023-11-15 - Price: 44201.69921875
# ^NSEBANK: Sell at 2023-11-16 - Price: 44161.55078125 - Profit: -40.15
# ^NSEBANK: Buy at 2023-11-28 - Price: 43880.94921875
# ^NSEBANK: Sell at 2023-11-29 - Price: 44566.44921875 - Profit: 685.50
# ^NSEBANK: Buy at 2023-11-30 - Price: 44481.75
#
# ^NSEBANK: Total Trades: 44
# ^NSEBANK: Total Profit: 12214.95
# ^NSEBANK: Average Profit per Trade: 277.61
# [*********************100%%**********************]  1 of 1 completed
# RELIANCE.NS: Buy at 2020-04-09 - Price: 1208.49462890625
# RELIANCE.NS: Sell at 2020-04-13 - Price: 1177.98388671875 - Profit: -30.51
# RELIANCE.NS: Buy at 2020-04-15 - Price: 1139.0528564453125
# RELIANCE.NS: Sell at 2020-04-16 - Price: 1157.08203125 - Profit: 18.03
# RELIANCE.NS: Buy at 2020-04-17 - Price: 1212.506591796875
# RELIANCE.NS: Sell at 2020-04-20 - Price: 1232.1207275390625 - Profit: 19.61
# RELIANCE.NS: Buy at 2020-04-21 - Price: 1225.7313232421875
# RELIANCE.NS: Sell at 2020-05-14 - Price: 1435.949951171875 - Profit: 210.22
# RELIANCE.NS: Buy at 2020-06-04 - Price: 1579.800048828125
# RELIANCE.NS: Sell at 2020-08-03 - Price: 2009.0 - Profit: 429.20
# RELIANCE.NS: Buy at 2020-09-18 - Price: 2305.699951171875
# RELIANCE.NS: Sell at 2020-09-21 - Price: 2255.85009765625 - Profit: -49.85
# RELIANCE.NS: Buy at 2020-10-14 - Price: 2287.5
# RELIANCE.NS: Sell at 2020-10-15 - Price: 2206.5 - Profit: -81.00
# RELIANCE.NS: Buy at 2020-12-09 - Price: 2026.949951171875
# RELIANCE.NS: Sell at 2020-12-10 - Price: 2007.0 - Profit: -19.95
# RELIANCE.NS: Buy at 2020-12-18 - Price: 1991.550048828125
# RELIANCE.NS: Sell at 2020-12-21 - Price: 1939.699951171875 - Profit: -51.85
# RELIANCE.NS: Buy at 2021-01-19 - Price: 2016.4000244140625
# RELIANCE.NS: Sell at 2021-01-20 - Price: 2054.699951171875 - Profit: 38.30
# RELIANCE.NS: Buy at 2021-01-21 - Price: 2099.39990234375
# RELIANCE.NS: Sell at 2021-01-25 - Price: 1941.0 - Profit: -158.40
# RELIANCE.NS: Buy at 2021-02-15 - Price: 2032.5999755859375
# RELIANCE.NS: Sell at 2021-02-22 - Price: 2008.0999755859375 - Profit: -24.50
# RELIANCE.NS: Buy at 2021-02-24 - Price: 2061.0
# RELIANCE.NS: Sell at 2021-03-12 - Price: 2137.60009765625 - Profit: 76.60
# RELIANCE.NS: Buy at 2021-05-19 - Price: 1997.050048828125
# RELIANCE.NS: Sell at 2021-05-20 - Price: 1985.4000244140625 - Profit: -11.65
# RELIANCE.NS: Buy at 2021-05-21 - Price: 2002.550048828125
# RELIANCE.NS: Sell at 2021-05-24 - Price: 1985.6500244140625 - Profit: -16.90
# RELIANCE.NS: Buy at 2021-05-28 - Price: 2094.800048828125
# RELIANCE.NS: Sell at 2021-06-22 - Price: 2225.75 - Profit: 130.95
# RELIANCE.NS: Buy at 2021-08-11 - Price: 2117.300048828125
# RELIANCE.NS: Sell at 2021-08-12 - Price: 2110.5 - Profit: -6.80
# RELIANCE.NS: Buy at 2021-08-13 - Price: 2145.64990234375
# RELIANCE.NS: Sell at 2021-08-16 - Price: 2173.5 - Profit: 27.85
# RELIANCE.NS: Buy at 2021-08-17 - Price: 2164.25
# RELIANCE.NS: Sell at 2021-10-21 - Price: 2622.5 - Profit: 458.25
# RELIANCE.NS: Buy at 2022-01-04 - Price: 2458.10009765625
# RELIANCE.NS: Sell at 2022-01-05 - Price: 2469.60009765625 - Profit: 11.50
# RELIANCE.NS: Buy at 2022-01-07 - Price: 2436.0
# RELIANCE.NS: Sell at 2022-01-10 - Price: 2438.0 - Profit: 2.00
# RELIANCE.NS: Buy at 2022-01-11 - Price: 2455.550048828125
# RELIANCE.NS: Sell at 2022-01-20 - Price: 2477.449951171875 - Profit: 21.90
# RELIANCE.NS: Buy at 2022-03-22 - Price: 2531.14990234375
# RELIANCE.NS: Sell at 2022-04-07 - Price: 2572.85009765625 - Profit: 41.70
# RELIANCE.NS: Buy at 2022-04-21 - Price: 2782.10009765625
# RELIANCE.NS: Sell at 2022-05-04 - Price: 2693.64990234375 - Profit: -88.45
# RELIANCE.NS: Buy at 2022-06-02 - Price: 2724.300048828125
# RELIANCE.NS: Sell at 2022-06-13 - Price: 2662.89990234375 - Profit: -61.40
# RELIANCE.NS: Buy at 2022-08-01 - Price: 2574.85009765625
# RELIANCE.NS: Sell at 2022-08-02 - Price: 2584.64990234375 - Profit: 9.80
# RELIANCE.NS: Buy at 2022-08-03 - Price: 2606.35009765625
# RELIANCE.NS: Sell at 2022-08-22 - Price: 2606.60009765625 - Profit: 0.25
# RELIANCE.NS: Buy at 2022-08-23 - Price: 2646.800048828125
# RELIANCE.NS: Sell at 2022-08-25 - Price: 2632.050048828125 - Profit: -14.75
# RELIANCE.NS: Buy at 2022-10-24 - Price: 2479.85009765625
# RELIANCE.NS: Sell at 2022-10-25 - Price: 2441.550048828125 - Profit: -38.30
# RELIANCE.NS: Buy at 2022-10-27 - Price: 2451.14990234375
# RELIANCE.NS: Sell at 2022-10-28 - Price: 2526.14990234375 - Profit: 75.00
# RELIANCE.NS: Buy at 2022-10-31 - Price: 2549.60009765625
# RELIANCE.NS: Sell at 2022-11-21 - Price: 2550.89990234375 - Profit: 1.30
# RELIANCE.NS: Buy at 2022-11-28 - Price: 2707.550048828125
# RELIANCE.NS: Sell at 2022-12-06 - Price: 2690.199951171875 - Profit: -17.35
# RELIANCE.NS: Buy at 2023-04-17 - Price: 2367.449951171875
# RELIANCE.NS: Sell at 2023-05-16 - Price: 2453.800048828125 - Profit: 86.35
# RELIANCE.NS: Buy at 2023-05-29 - Price: 2520.60009765625
# RELIANCE.NS: Sell at 2023-05-31 - Price: 2469.89990234375 - Profit: -50.70
# RELIANCE.NS: Buy at 2023-06-14 - Price: 2551.85009765625
# RELIANCE.NS: Sell at 2023-06-22 - Price: 2535.5 - Profit: -16.35
# RELIANCE.NS: Buy at 2023-07-03 - Price: 2615.699951171875
# RELIANCE.NS: Sell at 2023-07-20 - Price: 2619.85009765625 - Profit: 4.15
# RELIANCE.NS: Buy at 2023-11-15 - Price: 2356.449951171875
# RELIANCE.NS: Sell at 2023-11-16 - Price: 2360.699951171875 - Profit: 4.25
# RELIANCE.NS: Buy at 2023-11-17 - Price: 2355.550048828125
# RELIANCE.NS: Sell at 2023-11-20 - Price: 2349.35009765625 - Profit: -6.20
# RELIANCE.NS: Buy at 2023-11-21 - Price: 2378.89990234375
#
# RELIANCE.NS: Total Trades: 38
# RELIANCE.NS: Total Profit: 922.30
# RELIANCE.NS: Average Profit per Trade: 24.27
# [*********************100%%**********************]  1 of 1 completed
# SBIN.NS: Buy at 2020-02-20 - Price: 327.6499938964844
# SBIN.NS: Sell at 2020-02-24 - Price: 322.95001220703125 - Profit: -4.70
# SBIN.NS: Buy at 2020-02-25 - Price: 326.79998779296875
# SBIN.NS: Sell at 2020-02-27 - Price: 321.95001220703125 - Profit: -4.85
# SBIN.NS: Buy at 2020-06-08 - Price: 186.8000030517578
# SBIN.NS: Sell at 2020-06-09 - Price: 184.4499969482422 - Profit: -2.35
# SBIN.NS: Buy at 2020-06-10 - Price: 187.6999969482422
# SBIN.NS: Sell at 2020-06-15 - Price: 173.6999969482422 - Profit: -14.00
# SBIN.NS: Buy at 2020-06-19 - Price: 184.5
# SBIN.NS: Sell at 2020-06-26 - Price: 184.60000610351562 - Profit: 0.10
# SBIN.NS: Buy at 2020-07-06 - Price: 188.0500030517578
# SBIN.NS: Sell at 2020-07-14 - Price: 186.0500030517578 - Profit: -2.00
# SBIN.NS: Buy at 2020-07-23 - Price: 198.25
# SBIN.NS: Sell at 2020-07-24 - Price: 191.9499969482422 - Profit: -6.30
# SBIN.NS: Buy at 2020-08-12 - Price: 203.3000030517578
# SBIN.NS: Sell at 2020-08-17 - Price: 193.10000610351562 - Profit: -10.20
# SBIN.NS: Buy at 2020-08-24 - Price: 201.4499969482422
# SBIN.NS: Sell at 2020-09-04 - Price: 206.60000610351562 - Profit: 5.15
# SBIN.NS: Buy at 2020-10-12 - Price: 198.6999969482422
# SBIN.NS: Sell at 2020-10-13 - Price: 195.6999969482422 - Profit: -3.00
# SBIN.NS: Buy at 2020-10-14 - Price: 200.0500030517578
# SBIN.NS: Sell at 2020-10-15 - Price: 192.85000610351562 - Profit: -7.20
# SBIN.NS: Buy at 2020-10-16 - Price: 195.9499969482422
# SBIN.NS: Sell at 2020-10-19 - Price: 204.0 - Profit: 8.05
# SBIN.NS: Buy at 2020-10-20 - Price: 203.0500030517578
# SBIN.NS: Sell at 2020-10-26 - Price: 196.6999969482422 - Profit: -6.35
# SBIN.NS: Buy at 2020-11-03 - Price: 204.75
# SBIN.NS: Sell at 2020-11-06 - Price: 219.1999969482422 - Profit: 14.45
# SBIN.NS: Buy at 2020-11-11 - Price: 234.1999969482422
# SBIN.NS: Sell at 2020-12-21 - Price: 254.6999969482422 - Profit: 20.50
# SBIN.NS: Buy at 2021-01-06 - Price: 285.04998779296875
# SBIN.NS: Sell at 2021-01-21 - Price: 294.8500061035156 - Profit: 9.80
# SBIN.NS: Buy at 2021-02-02 - Price: 333.1000061035156
# SBIN.NS: Sell at 2021-02-03 - Price: 335.95001220703125 - Profit: 2.85
# SBIN.NS: Buy at 2021-02-10 - Price: 392.25
# SBIN.NS: Sell at 2021-02-22 - Price: 389.5 - Profit: -2.75
# SBIN.NS: Buy at 2021-05-05 - Price: 355.3999938964844
# SBIN.NS: Sell at 2021-05-06 - Price: 355.54998779296875 - Profit: 0.15
# SBIN.NS: Buy at 2021-05-07 - Price: 358.25
# SBIN.NS: Sell at 2021-05-10 - Price: 361.70001220703125 - Profit: 3.45
# SBIN.NS: Buy at 2021-05-11 - Price: 364.6499938964844
# SBIN.NS: Sell at 2021-05-12 - Price: 367.70001220703125 - Profit: 3.05
# SBIN.NS: Buy at 2021-05-14 - Price: 360.45001220703125
# SBIN.NS: Sell at 2021-06-09 - Price: 421.45001220703125 - Profit: 61.00
# SBIN.NS: Buy at 2021-07-29 - Price: 441.54998779296875
# SBIN.NS: Sell at 2021-08-06 - Price: 435.6499938964844 - Profit: -5.90
# SBIN.NS: Buy at 2021-09-14 - Price: 433.0
# SBIN.NS: Sell at 2021-09-20 - Price: 437.45001220703125 - Profit: 4.45
# SBIN.NS: Buy at 2021-09-23 - Price: 449.79998779296875
# SBIN.NS: Sell at 2021-09-24 - Price: 440.75 - Profit: -9.05
# SBIN.NS: Buy at 2021-09-27 - Price: 446.6000061035156
# SBIN.NS: Sell at 2021-09-28 - Price: 444.8999938964844 - Profit: -1.70
# SBIN.NS: Buy at 2021-09-29 - Price: 460.0
# SBIN.NS: Sell at 2021-11-11 - Price: 509.6000061035156 - Profit: 49.60
# SBIN.NS: Buy at 2022-01-05 - Price: 492.3999938964844
# SBIN.NS: Sell at 2022-01-06 - Price: 491.70001220703125 - Profit: -0.70
# SBIN.NS: Buy at 2022-01-07 - Price: 491.25
# SBIN.NS: Sell at 2022-01-10 - Price: 503.6499938964844 - Profit: 12.40
# SBIN.NS: Buy at 2022-01-11 - Price: 505.95001220703125
# SBIN.NS: Sell at 2022-01-21 - Price: 502.70001220703125 - Profit: -3.25
# SBIN.NS: Buy at 2022-01-27 - Price: 528.9500122070312
# SBIN.NS: Sell at 2022-02-11 - Price: 529.5999755859375 - Profit: 0.65
# SBIN.NS: Buy at 2022-03-23 - Price: 490.6499938964844
# SBIN.NS: Sell at 2022-03-24 - Price: 487.1000061035156 - Profit: -3.55
# SBIN.NS: Buy at 2022-03-25 - Price: 490.70001220703125
# SBIN.NS: Sell at 2022-03-28 - Price: 497.5 - Profit: 6.80
# SBIN.NS: Buy at 2022-03-29 - Price: 495.0
# SBIN.NS: Sell at 2022-03-30 - Price: 494.29998779296875 - Profit: -0.70
# SBIN.NS: Buy at 2022-03-31 - Price: 493.54998779296875
# SBIN.NS: Sell at 2022-04-18 - Price: 509.5 - Profit: 15.95
# SBIN.NS: Buy at 2022-04-19 - Price: 511.79998779296875
# SBIN.NS: Sell at 2022-04-20 - Price: 509.29998779296875 - Profit: -2.50
# SBIN.NS: Buy at 2022-07-04 - Price: 473.45001220703125
# SBIN.NS: Sell at 2022-07-05 - Price: 472.1499938964844 - Profit: -1.30
# SBIN.NS: Buy at 2022-07-06 - Price: 479.95001220703125
# SBIN.NS: Sell at 2022-07-15 - Price: 479.1000061035156 - Profit: -0.85
# SBIN.NS: Buy at 2022-07-18 - Price: 490.29998779296875
# SBIN.NS: Sell at 2022-08-08 - Price: 520.4000244140625 - Profit: 30.10
# SBIN.NS: Buy at 2022-09-08 - Price: 544.6500244140625
# SBIN.NS: Sell at 2022-09-23 - Price: 550.5999755859375 - Profit: 5.95
# SBIN.NS: Buy at 2022-10-25 - Price: 578.5499877929688
# SBIN.NS: Sell at 2022-11-14 - Price: 592.5499877929688 - Profit: 14.00
# SBIN.NS: Buy at 2022-11-15 - Price: 600.8499755859375
# SBIN.NS: Sell at 2022-11-21 - Price: 598.0999755859375 - Profit: -2.75
# SBIN.NS: Buy at 2023-03-03 - Price: 561.2000122070312
# SBIN.NS: Sell at 2023-03-06 - Price: 561.7000122070312 - Profit: 0.50
# SBIN.NS: Buy at 2023-03-08 - Price: 564.7999877929688
# SBIN.NS: Sell at 2023-03-09 - Price: 558.9000244140625 - Profit: -5.90
# SBIN.NS: Buy at 2023-04-18 - Price: 545.8499755859375
# SBIN.NS: Sell at 2023-04-19 - Price: 540.2999877929688 - Profit: -5.55
# SBIN.NS: Buy at 2023-04-20 - Price: 544.7999877929688
# SBIN.NS: Sell at 2023-05-18 - Price: 574.2000122070312 - Profit: 29.40
# SBIN.NS: Buy at 2023-07-07 - Price: 593.5999755859375
# SBIN.NS: Sell at 2023-07-14 - Price: 584.4000244140625 - Profit: -9.20
# SBIN.NS: Buy at 2023-07-17 - Price: 601.0999755859375
# SBIN.NS: Sell at 2023-08-02 - Price: 598.4500122070312 - Profit: -2.65
# SBIN.NS: Buy at 2023-09-12 - Price: 588.3499755859375
# SBIN.NS: Sell at 2023-09-13 - Price: 596.4500122070312 - Profit: 8.10
# SBIN.NS: Buy at 2023-09-14 - Price: 597.2999877929688
# SBIN.NS: Sell at 2023-09-21 - Price: 588.1500244140625 - Profit: -9.15
# SBIN.NS: Buy at 2023-09-22 - Price: 598.1500244140625
# SBIN.NS: Sell at 2023-09-26 - Price: 594.4000244140625 - Profit: -3.75
# SBIN.NS: Buy at 2023-10-03 - Price: 602.9500122070312
# SBIN.NS: Sell at 2023-10-04 - Price: 586.25 - Profit: -16.70
# SBIN.NS: Buy at 2023-11-10 - Price: 579.5
# SBIN.NS: Sell at 2023-11-13 - Price: 581.3499755859375 - Profit: 1.85
# SBIN.NS: Buy at 2023-11-15 - Price: 584.7000122070312
# SBIN.NS: Sell at 2023-11-16 - Price: 584.6500244140625 - Profit: -0.05
# SBIN.NS: Buy at 2023-12-04 - Price: 594.7000122070312
# SBIN.NS: Sell at 2023-12-05 - Price: 608.25 - Profit: 13.55
# SBIN.NS: Buy at 2023-12-06 - Price: 608.4500122070312
#
# SBIN.NS: Total Trades: 55
# SBIN.NS: Total Profit: 172.95
# SBIN.NS: Average Profit per Trade: 3.14

# %%
total_accuracy_rate = 0
total_trades = 0
total_winning_trades = 0
total_losing_trades = 0
total_win_loss_ratio = 0
total_profit_factor = 0

for symbol in ticker_symbols:
    
    df_trades = pd.read_csv(f'{symbol}_trades_output.csv')

    if not df_trades.empty:
        accuracy_rate = (df_trades['Profit'] > 0).sum() / len(df_trades)

        trades = len(df_trades)
        winning_trades = (df_trades['Profit'] > 0).sum()
        losing_trades = trades - winning_trades

        win_loss_ratio = winning_trades / max(1, losing_trades)
        profit_factor = abs(df_trades['Profit'][df_trades['Profit'] > 0].sum() / df_trades['Profit'][df_trades['Profit'] < 0].sum())

        print(f"\nMetrics for {symbol}:")
        print(f"Accuracy Rate: {accuracy_rate * 100:.2f}%")
        print(f"Total Trades: {trades}")
        print(f"Winning Trades: {winning_trades}")
        print(f"Losing Trades: {losing_trades}")
        print(f"Win/Loss Ratio: {win_loss_ratio:.2f}")
        print(f"Profit Factor: {profit_factor:.2f}")

        total_accuracy_rate += accuracy_rate
        total_trades += trades
        total_winning_trades += winning_trades
        total_losing_trades += losing_trades
        total_win_loss_ratio += win_loss_ratio
        total_profit_factor += profit_factor

if total_trades > 0:
    avg_accuracy_rate = total_accuracy_rate / len(ticker_symbols)
    avg_win_loss_ratio = total_win_loss_ratio / len(ticker_symbols)
    avg_profit_factor = total_profit_factor / len(ticker_symbols)

    print("\nOverall Metrics:")
    print(f"Average Accuracy Rate: {avg_accuracy_rate * 100:.2f}%")
    print(f"Total Trades Across All Symbols: {total_trades}")
    print(f"Average Win/Loss Ratio Across All Symbols: {avg_win_loss_ratio:.2f}")
    print(f"Average Profit Factor Across All Symbols: {avg_profit_factor:.2f}")
else:
    print("No trades executed based on the strategy.")
# Out:
# Metrics for ^NSEI:
# Accuracy Rate: 52.38%
# Total Trades: 42
# Winning Trades: 22
# Losing Trades: 20
# Win/Loss Ratio: 1.10
# Profit Factor: 2.36
#
# Metrics for ^NSEBANK:
# Accuracy Rate: 65.91%
# Total Trades: 44
# Winning Trades: 29
# Losing Trades: 15
# Win/Loss Ratio: 1.93
# Profit Factor: 2.38
#
# Metrics for RELIANCE.NS:
# Accuracy Rate: 52.63%
# Total Trades: 38
# Winning Trades: 20
# Losing Trades: 18
# Win/Loss Ratio: 1.11
# Profit Factor: 2.24
#
# Metrics for SBIN.NS:
# Accuracy Rate: 45.45%
# Total Trades: 55
# Winning Trades: 25
# Losing Trades: 30
# Win/Loss Ratio: 0.83
# Profit Factor: 2.16
#
# Overall Metrics:
# Average Accuracy Rate: 54.09%
# Total Trades Across All Symbols: 179
# Average Win/Loss Ratio Across All Symbols: 1.24
# Average Profit Factor Across All Symbols: 2.29

# %%
for symbol in ticker_symbols:
    df_trades = pd.read_csv(f'{symbol}_trades_output.csv')

    if not df_trades.empty:
        max_loss = df_trades['Profit'].min()
        max_gain = df_trades['Profit'].max()

        df_trades['Cumulative Profit'] = df_trades['Profit'].cumsum()
        df_trades['Previous Peak'] = df_trades['Cumulative Profit'].cummax()
        df_trades['Drawdown'] = df_trades['Cumulative Profit'] - df_trades['Previous Peak']
        max_drawdown = df_trades['Drawdown'].min()

        print(f"\nMetrics for {symbol}:")
        print(f"Max Loss: {max_loss:.2f}")
        print(f"Max Gain: {max_gain:.2f}")
        print(f"Max Drawdown: {max_drawdown:.2f}")
    else:
        print(f"{symbol}: No trades executed based on the strategy.")
# Out:
# Metrics for ^NSEI:
# Max Loss: -566.40
# Max Gain: 1441.50
# Max Drawdown: -687.85
#
# Metrics for ^NSEBANK:
# Max Loss: -1338.90
# Max Gain: 3765.95
# Max Drawdown: -2008.15
#
# Metrics for RELIANCE.NS:
# Max Loss: -158.40
# Max Gain: 458.25
# Max Drawdown: -347.25
#
# Metrics for SBIN.NS:
# Max Loss: -16.70
# Max Gain: 61.00
# Max Drawdown: -44.65
